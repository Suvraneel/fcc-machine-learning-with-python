# %% [markdown]
# <a href="https://colab.research.google.com/github/Suvraneel/fcc-machine-learning-with-python/blob/fcc-practice/stocksJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
cwd = os.getcwd()

# %%
# Data scraping backup
# !pip install jugaad-data

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# !pip install nsepy
# from nsepy import get_history
# from datetime import date
# data = get_history(symbol="SBIN", start=date(2019,1,1), end=date(2020,12,30))
# data[['Close']].plot()

# %%
# !git clone -b '4.0' https://github.com/NSEDownload/NSEDownload
# !pip3 install NSEDownload/dist/NSEDownload-4.0.tar.gz
# Out:
# Cloning into 'NSEDownload'...
# remote: Enumerating objects: 484, done.
# remote: Counting objects: 100% (484/484), done.
# remote: Compressing objects: 100% (352/352), done.
# remote: Total 484 (delta 261), reused 325 (delta 126), pack-reused 0
# Receiving objects: 100% (484/484), 668.71 KiB | 24.77 MiB/s, done.
# Resolving deltas: 100% (261/261), done.
# Processing ./NSEDownload/dist/NSEDownload-4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from NSEDownload==4.0) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from NSEDownload==4.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from NSEDownload==4.0) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from NSEDownload==4.0) (1.1.5)
# Collecting timedelta
#   Downloading timedelta-2020.12.3.tar.gz (1.6 kB)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 6.0 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->NSEDownload==4.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->NSEDownload==4.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->NSEDownload==4.0) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->NSEDownload==4.0) (57.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->NSEDownload==4.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->NSEDownload==4.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->NSEDownload==4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->NSEDownload==4.0) (3.0.4)
# Building wheels for collected packages: NSEDownload, python-Levenshtein, timedelta
#   Building wheel for NSEDownload (setup.py) ... done
#   Created wheel for NSEDownload: filename=NSEDownload-4.0-py3-none-any.whl size=18564 sha256=dad4cc08c9db78dacd2a0ae1179408ececeb64da368512782d967d1e19902891
#   Stored in directory: /root/.cache/pip/wheels/1d/c6/06/c12dd070b8c82e167702f0810ca29461c2abd6e59e5428da0b
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149867 sha256=b77f2dd344f3cbfbc69fd9fc0f6a877360eb5ec1429e5ae9dac22f02d2c70394
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
#   Building wheel for timedelta (setup.py) ... done
#   Created wheel for timedelta: filename=timedelta-2020.12.3-py3-none-any.whl size=1603 sha256=350214dac3f4467a81bc4e5c25371e5a2289ee037136e2c9942fc2277f8d6293
#   Stored in directory: /root/.cache/pip/wheels/4e/b6/37/4e3dcf4958e062171a2ce6bbe5a5c1a9186913c69e63a7cec9
# Successfully built NSEDownload python-Levenshtein timedelta
# Installing collected packages: timedelta, python-Levenshtein, fuzzywuzzy, NSEDownload
# Successfully installed NSEDownload-4.0 fuzzywuzzy-0.18.0 python-Levenshtein-0.12.2 timedelta-2020.12.3

# %% [markdown]
# # Example Symbols
# ![image.png](data:image/png;base64,...)

# %%
def convert_date(x,y,z):
    orig_date = datetime(x,y,z)
    orig_date = str(orig_date)
    d = datetime.strptime(orig_date, '%Y-%m-%d %H:%M:%S')
    d = d.strftime('%m/%d/%y')
    return d

# %%
from NSEDownload import stocks
# symbol = input("Enter symbol of stock\n") # Tested : SBIN, AXISBANK, RELIANCE, IOC, BHARTIARTL
symbol = "BHARTIARTL"
df = stocks.get_data(stockSymbol = symbol, start_date = '1-1-2018', end_date = '20-11-2021')
df = stocks.get_adjusted_data(symbol, df)
from google.colab import data_table
data_table.DataTable(df, include_index=True, num_rows_per_page=10)
# Out:
# BHARTIARTL
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th
td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-17</th>
#       <td>BHARTIARTL</td>
#       <td>EQ</td>
#       <td>724.55</td>
#       <td>732.35</td>
#       <td>716.25</td>
#       <td>720.50</td>
#       <td>720.05</td>
#       <td>724.59</td>
#       <td>8002927</td>
#       <td>5.798838e+09</td>
#       <td>109358</td>
#       <td>4657808</td>
#       <td>58.20</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-18</th>
#       <td>BHARTIARTL</td>
#       <td>EQ</td>
#       <td>720.60</td>
#       <td>723.45</td>
#       <td>708.00</td>
#       <td>714.25</td>
#       <td>714.35</td>
#       <td>715.55</td>
#       <td>4469597</td>
#       <td>3.198210e+09</td>
#       <td>102930</td>
#       <td>1777562</td>
#       <td>39.77</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <p>961 rows × 14 columns</p>
# </div>

# %%
# from datetime import date
# from jugaad_data.nse import bhavcopy_save, bhavcopy_fo_save

# # Download bhavcopy
# bhavcopy_save(date(2020,1,1), "/content/drive/MyDrive/NSEdata/")

# # Download bhavcopy for futures and options
# bhavcopy_fo_save(date(2020,1,1), "/content/drive/MyDrive/NSEdata/")

# # Download stock data to pandas dataframe
# from jugaad_data.nse import stock_df
# df = stock_df(symbol="SBIN", from_date=date(2019,1,1),
#             to_date=date(2020,12,30), series="EQ")
# df.head(15)

# %%
# s = "/content/drive/MyDrive/nse_data_legacy.csv"
df = df.drop('Series', 1)
dataset_train = pd.DataFrame(df)
dataset_train = df
training_set = dataset_train.iloc[:, 1:2].values
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-08', '2018-01-09', '2018-01-10',
#                '2018-01-11', '2018-01-12',
#                ...
#                '2021-11-04', '2021-11-08', '2021-11-09', '2021-11-10',
#                '2021-11-11', '2021-11-12', '2021-11-15', '2021-11-16',
#                '2021-11-17', '2021-11-18'],
#               dtype='datetime64[ns]', name='Date', length=961, freq=None)

# %%
print(df.index.min(), df.index.max()) 
print(dataset_train.shape)
data_table.DataTable(dataset_train, include_index=True, num_rows_per_page=10)
# Out:
# 2018-01-01 00:00:00 2021-11-18 00:00:00
# (961, 13)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>Open Price</th>
#       <th>High Price</th>
#       <th>Low Price</th>
#       <th>Last Price</th>
#       <th>Close Price</th>
#       <th>Average Price</th>
#       <th>Total Traded Quantity</th>
#       <th>Turnover</th>
#       <th>No. of Trades</th>
#       <th>Deliverable Qty</th>
#       <th>% Dly Qt to Traded Qty</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-01-01</th>
#       <td>BHARTIARTL</td>
#       <td>531.00</td>
#       <td>538.10</td>
#       <td>525.40</td>
#       <td>527.95</td>
#       <td>527.90</td>
#       <td>532.51</td>
#       <td>4333190</td>
#       <td>2.307486e+09</td>
#       <td>35087</td>
#       <td>1340521</td>
#       <td>30.94</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2018-01-02</th>
#       <td>BHARTIARTL</td>
#       <td>532.90</td>
#       <td>532.90</td>
#       <td>511.85</td>
#       <td>516.70</td>
#       <td>516.55</td>
#       <td>521.44</td>
#       <td>4724570</td>
#       <td>2.463556e+09</td>
#       <td>52103</td>
#       <td>2322487</td>
#       <td>49.16</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2018-01-03</th>
#       <td>BHARTIARTL</td>
#       <td>519.15</td>
#       <td>525.50</td>
#       <td>514.75</td>
#       <td>516.75</td>
#       <td>518.20</td>
#       <td>521.37</td>
#       <td>5707905</td>
#       <td>2.975947e+09</td>
#       <td>47040</td>
#       <td>3499441</td>
#       <td>61.31</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2018-01-04</th>
#       <td>BHARTIARTL</td>
#       <td>519.00</td>
#       <td>527.20</td>
#       <td>514.50</td>
#       <td>523.90</td>
#       <td>523.00</td>
#       <td>520.70</td>
#       <td>5366018</td>
#       <td>2.794101e+09</td>
#       <td>60595</td>
#       <td>3133073</td>
#       <td>58.39</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2018-01-05</th>
#       <td>BHARTIARTL</td>
#       <td>525.00</td>
#       <td>542.50</td>
#       <td>518.55</td>
#       <td>539.90</td>
#       <td>540.00</td>
#       <td>534.11</td>
#       <td>7218024</td>
#       <td>3.855251e+09</td>
#       <td>94131</td>
#       <td>2918981</td>
#       <td>40.44</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2021-11-12</th>
#       <td>BHARTIARTL</td>
#       <td>733.00</td>
#       <td>745.00</td>
#       <td>725.25</td>
#       <td>741.70</td>
#       <td>743.50</td>
#       <td>739.18</td>
#       <td>9207508</td>
#       <td>6.806028e+09</td>
#       <td>143918</td>
#       <td>4085440</td>
#       <td>44.37</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-15</th>
#       <td>BHARTIARTL</td>
#       <td>740.00</td>
#       <td>746.00</td>
#       <td>736.20</td>
#       <td>738.85</td>
#       <td>737.55</td>
#       <td>740.17</td>
#       <td>5454742</td>
#       <td>4.037414e+09</td>
#       <td>106730</td>
#       <td>2591471</td>
#       <td>47.51</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-16</th>
#       <td>BHARTIARTL</td>
#       <td>741.35</td>
#       <td>742.05</td>
#       <td>727.05</td>
#       <td>728.50</td>
#       <td>730.30</td>
#       <td>735.22</td>
#       <td>4639931</td>
#       <td>3.411373e+09</td>
#       <td>85245</td>
#       <td>2135986</td>
#       <td>46.03</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-17</th>
#       <td>BHARTIARTL</td>
#       <td>724.55</td>
#       <td>732.35</td>
#       <td>716.25</td>
#       <td>720.50</td>
#       <td>720.05</td>
#       <td>724.59</td>
#       <td>8002927</td>
#       <td>5.798838e+09</td>
#       <td>109358</td>
#       <td>4657808</td>
#       <td>58.20</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2021-11-18</th>
#       <td>BHARTIARTL</td>
#       <td>720.60</td>
#       <td>723.45</td>
#       <td>708.00</td>
#       <td>714.25</td>
#       <td>714.35</td>
#       <td>715.55</td>
#       <td>4469597</td>
#       <td>3.198210e+09</td>
#       <td>102930</td>
#       <td>1777562</td>
#       <td>39.77</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <p>961 rows × 13 columns</p>
# </div>

# %% [markdown]
# ### Drop columns which contain missing value
# Read documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)

# %%
df = df.dropna(axis = "columns")
df.head(5)
# Out:
#                 Symbol  Open Price  ...  % Dly Qt to Traded Qty
# Date                                ...
# 2018-01-01  BHARTIARTL      531.00  ...                   30.94
# 2018-01-02  BHARTIARTL      532.90  ...                   49.16
# 2018-01-03  BHARTIARTL      519.15  ...                   61.31
# 2018-01-04  BHARTIARTL      519.00  ...                   58.39
# 2018-01-05  BHARTIARTL      525.00  ...                   40.44
#
# [5 rows x 13 columns]

# %%
df_close = df['Close Price']
df_close
# Out:
# Date
# 2018-01-01    527.90
# 2018-01-02    516.55
# 2018-01-03    518.20
# 2018-01-04    523.00
# 2018-01-05    540.00
#                ...
# 2021-11-12    743.50
# 2021-11-15    737.55
# 2021-11-16    730.30
# 2021-11-17    720.05
# 2021-11-18    714.35
# Name: Close Price, Length: 961, dtype: float64

# %%
df_close = df_close.values.reshape(-1,1)

# %% [markdown]
# ## Data Normalization
# In order to normalise the data, we need to scale it between 0 and 1 so we talk on a common scale. To accomplish this, we can use the preprocessing tool MinMaxScaler as seen below:

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
#Plot closing price
plt.plot(df_close)
plt.show()

scaler = MinMaxScaler(feature_range=(0, 1))
df_close = scaler.fit_transform(df_close)

# %% [markdown]
# ## Splitting into into train set, test set & validation set :
#
#  | train | test | val |
#  :------:|:----:|:----:
#  | 70 | 20 | 10 |

# %%
# Splitting dataset into training & testing set
train_size = int(len(df_close) * 0.70)
test_size = int(len(df_close) * 0.20)
valid_size = len(df_close) - train_size - test_size
# holding rest of the data for blackbox testing = without ever using b4
train, test, valid = df_close[0:train_size,:], df_close[train_size:train_size+test_size,:], df_close[train_size+test_size:len(df_close),:]
print(len(train), len(test))
# Out:
# 672 192

# %% [markdown]
# # Recursive Feature Elimination :
# - Forget irrelevant data from long back

# %% [markdown]
# ## Adding Timesteps
#
# LSTM network needs the data imported as a 3D array. To translate this 2D array into a 3D one, we use a short timestep to loop through the data and create smaller partitions and feed them into the model. The final array is then reshaped into training samples, x number of timesteps, and 1 feature per step. The code below represents this concept:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#     time_steps = 3
#     for i in range(time_steps, train_scaled.shape[0]):
#         x_train.append(train_scaled[i - time_steps:i])
#         y_train.append(train_scaled[i, 0])
#
# We have implemented a time step of 3 days. Using this technique, we allow our network to look back 3 days on our data to predict the subsequent day). The figure below represents how our implementation uses this concept and how the first 3 samples for Close price would generate the 4th sample and so on.This will generate a matrix of shape (3,1), 3 being the time steps and 1 the number of features (Close price).

# %%
    # time_steps = 3
    # trainX = []
    # trainY = []
    # for i in range(time_steps, train.shape[0]):
    #     trainX.append(train[i - time_steps:i])
    #     trainY.append(train[i, 0])

    # # Testing Data Transformation
    # testX = []
    # testY = []
    # for i in range(time_steps, test.shape[0]):
    #     testX.append(test[i - time_steps:i])
    #     testY.append(test[i, 0])

    # testX, testY = np.array(testX), np.array(testY)
    # testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# Normalize the values such that prices are reduced to normalized values and prediction of stock movement instead of actual prices
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1): # keep only similar value data if a data point is too far of the last one jump to the next value
	dataX, dataY = [], []       # put this in data x
	for i in range(len(dataset)-look_back-1): # let dataY have only output values
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
validX, validY = create_dataset(valid, look_back)

# %%
trainX
# Out:
# array([0.51871658, 0.55582233, 0.50420168, 0.48990505, 0.4824839 ,
#        0.50070937, 0.48935938, 0.47833679, 0.46251228, 0.46829641,
#        0.45760122, 0.46393103, 0.44821565, 0.45127142, 0.38011568,
#        0.36527338, 0.33886282, 0.33886282, 0.3372258 , 0.3340609 ,
#        0.2990287 , 0.33798974, 0.33569792, 0.31627196, 0.31528975,
#        0.29935611, 0.30350322, 0.32620321, 0.31343446, 0.29324457,
#        0.28156717, 0.28975226, 0.29313544, 0.28538688, 0.30601331,
#        0.30077486, 0.31681764, 0.31256139, 0.31081524, 0.29706428,
#        0.28058496, 0.25723016, 0.25308305, 0.25493834, 0.29728255,
#        0.30765033, 0.29957438, 0.29488159, 0.28680563, 0.24948161,
#        0.25111863, 0.28997053, 0.28429554, 0.27796573, 0.29717341,
#        0.27905708, 0.24740805, 0.23955037, 0.25504747, 0.23944123,
#        0.37051184, 0.38229837, 0.37203972, 0.366583  , 0.37073011,
#        0.37051184, 0.35861617, 0.34868493, 0.37869693, 0.3814253 ,
#        0.37465895, 0.40063298, 0.40161519, 0.39834115, 0.41154644,
#        0.46862381, 0.48750409, 0.4941613 , 0.5001637 , 0.52013533,
#        0.52144494, 0.49994543, 0.44941613, 0.44723344, 0.44625123,
#        0.46076612, 0.46240314, 0.49045073, 0.50976754, 0.54130743,
#        0.57066463, 0.55462185, 0.55298483, 0.54338099, 0.55494925,
#        0.55571319, 0.61038961, 0.61006221, 0.57382953, 0.56324348,
#        0.5680454 , 0.53377715, 0.54545455, 0.54698243, 0.53759686,
#        0.51980792, 0.50856706, 0.51391466, 0.50507476, 0.52722907,
#        0.51031322, 0.46032959, 0.45498199, 0.39201135, 0.45072574,
#        0.39168395, 0.36963876, 0.30601331, 0.34792099, 0.38699116,
#        0.26628833, 0.25908545, 0.31376187, 0.40456182, 0.35708829,
#        0.31801812, 0.33951763, 0.29684601, 0.30252101, 0.40347048,
#        0.38480847, 0.44385027, 0.49514351, 0.49143294, 0.46949689,
#        0.47386227, 0.44734257, 0.46960602, 0.47157045, 0.45978391,
#        0.4559642 , 0.45552767, 0.43719306, 0.45978391, 0.49972716,
#        0.53945214, 0.52973917, 0.56891848, 0.52973917, 0.53410455,
#        0.5475281 , 0.59914875, 0.59063625, 0.55549493, 0.58659828,
#        0.55156608, 0.68416457, 0.67379679, 0.67488814, 0.6719415 ,
#        0.59783914, 0.6062425 , 0.60547856, 0.58332424, 0.5974026 ,
#        0.59532904, 0.58125068, 0.62665066, 0.65262469, 0.65437084,
#        0.61650115, 0.61497326, 0.58168722, 0.59969442, 0.57917713,
#        0.56651752, 0.60700644, 0.60144058, 0.62675979, 0.64542181,
#        0.64051075, 0.59369202, 0.59729346, 0.60034923, 0.61497326,
#        0.59914875, 0.59980356, 0.59609298, 0.64629488, 0.63570883,
#        0.6150824 , 0.60231365, 0.61835643, 0.63156172, 0.65797228,
#        0.66353814, 0.60733384, 0.60547856, 0.61420932, 0.63385354,
#        0.61639201, 0.61944778, 0.61519153, 0.59827567, 0.59838481,
#        0.60951653, 0.61300884, 0.58354251, 0.58823529, 0.57186511,
#        0.57546655, 0.59718433, 0.58921751, 0.60122231, 0.59696606,
#        0.5800502 , 0.57262905, 0.54567281, 0.53093965, 0.51522427,
#        0.52591946, 0.54676416, 0.52428244, 0.51271418, 0.52722907,
#        0.53104878, 0.5001637 , 0.49285169, 0.51969879, 0.49710793,
#        0.56946415, 0.57884972, 0.55145695, 0.51904398, 0.50223726,
#        0.46436757, 0.47779112, 0.46273055, 0.45028921, 0.41198298,
#        0.43697479, 0.42868056, 0.42267816])

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
validX = np.reshape(validX, (validX.shape[0], 1, validX.shape[1]))

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import time #helper libraries

# %% [markdown]
# Building the LSTM
# In order to build the LSTM, we need to import a couple of modules from Keras:
#
#     Sequential for initializing the neural network
#     Dense for adding a densely connected neural network layer
#     LSTM for adding the Long Short-Term Memory layer
#     Dropout for adding dropout layers that prevent overfitting
#
# > [Understanding LSTM - References](https://colah.github.io/posts/2015-08-Understanding-LSTMs/)

# %%
regressor = Sequential()    # Init regressor
# 1st layer with Dropout regularisation
# * units = add 100 neurons is the dimensionality of the output space
# * return_sequences = True to stack LSTM layers so the next LSTM layer has a three-dimensional sequence input
# * input_shape => Shape of the training dataset
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (trainX.shape[1], 1)))
# 20% of the layers will be dropped
regressor.add(Dropout(0.2))

# 2nd LSTM layer
# * units = add 50 neurons is the dimensionality of the output space
# * return_sequences = True to stack LSTM layers so the next LSTM layer has a three-dimensional sequence input
                                          # regressor.add(LSTM(units = 50, return_sequences = True))
# 20% of the layers will be dropped
                                          # regressor.add(Dropout(0.2))
# 3rd layer
                                          # regressor.add(LSTM(units = 50, return_sequences = True))
                                          # regressor.add(Dropout(0.2))

# 4th LSTM layer
# * units = add 100 neurons is the dimensionality of the output space
regressor.add(LSTM(units = 100))     # return = false
# 50% of the layers will be dropped
regressor.add(Dropout(0.2))

# Dense layer that specifies an output of one unit
regressor.add(Dense(units = 1))     #last layer
regressor.add(Activation('relu'))

regressor.summary()

# set project folder to generate flowchart for model
# tf.keras.utils.plot_model(regressor, to_file=os.path.join(project_folder, 'model_lstm.png'), show_shapes=True,
#                               show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 50)             10400
#
#  dropout_2 (Dropout)         (None, 1, 50)             0
#
#  lstm_3 (LSTM)               (None, 100)               60400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 70,901
# Trainable params: 70,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Once the model has been defined, we need to specify the metrics we want to use to track how well the model is behaving
# Further, specify the kind of optimizer to be used for training.
# The patience for model to have has also been defined and what is the rule defined for it.

# %%
start = time.time()
defined_metrics = [
        tf.keras.metrics.MeanSquaredError(name='MSE'),
        tf.keras.metrics.MeanAbsoluteError(name='MAE'),
    ]
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, mode='min', verbose=1)
regressor.compile(loss='mse', optimizer='rmsprop', metrics=defined_metrics)
print ('compilation time : ', time.time() - start)

# regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')      #adam = mean of sq. error b/w actual & predicted values
# regressor.fit(X_train, y_train, epochs =60, batch_size = 32) # epoch = 100 #validation_data=None #shuffle=True
# Out:
# compilation time :  0.015575647354125977

# %%
history = regressor.fit(
    trainX,
    trainY,
    batch_size=128,
    epochs=50,
    validation_split=0.05,
    callbacks=[callback])
# Out:
# Epoch 1/50
# 5/5 [==============================] - 5s 127ms/step - loss: 0.0800 - MSE: 0.0800 - MAE: 0.2225 - val_loss: 0.1912 - val_MSE: 0.1912 - val_MAE: 0.4343
# Epoch 2/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0533 - MSE: 0.0533 - MAE: 0.1699 - val_loss: 0.1369 - val_MSE: 0.1369 - val_MAE: 0.3669
# Epoch 3/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0365 - MSE: 0.0365 - MAE: 0.1359 - val_loss: 0.0936 - val_MSE: 0.0936 - val_MAE: 0.3025
# Epoch 4/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0260 - MSE: 0.0260 - MAE: 0.1186 - val_loss: 0.0633 - val_MSE: 0.0633 - val_MAE: 0.2477
# Epoch 5/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0209 - MSE: 0.0209 - MAE: 0.1147 - val_loss: 0.0445 - val_MSE: 0.0445 - val_MAE: 0.2067
# Epoch 6/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0182 - MSE: 0.0182 - MAE: 0.1122 - val_loss: 0.0345 - val_MSE: 0.0345 - val_MAE: 0.1812
# Epoch 7/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0170 - MSE: 0.0170 - MAE: 0.1112 - val_loss: 0.0307 - val_MSE: 0.0307 - val_MAE: 0.1708
# Epoch 8/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0156 - MSE: 0.0156 - MAE: 0.1067 - val_loss: 0.0279 - val_MSE: 0.0279 - val_MAE: 0.1629
# Epoch 9/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0134 - MSE: 0.0134 - MAE: 0.0982 - val_loss: 0.0225 - val_MSE: 0.0225 - val_MAE: 0.1458
# Epoch 10/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0114 - MSE: 0.0114 - MAE: 0.0905 - val_loss: 0.0185 - val_MSE: 0.0185 - val_MAE: 0.1321
# Epoch 11/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0088 - MSE: 0.0088 - MAE: 0.0794 - val_loss: 0.0129 - val_MSE: 0.0129 - val_MAE: 0.1097
# Epoch 12/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0071 - MSE: 0.0071 - MAE: 0.0700 - val_loss: 0.0093 - val_MSE: 0.0093 - val_MAE: 0.0924
# Epoch 13/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0053 - MSE: 0.0053 - MAE: 0.0607 - val_loss: 0.0057 - val_MSE: 0.0057 - val_MAE: 0.0717
# Epoch 14/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0035 - MSE: 0.0035 - MAE: 0.0479 - val_loss: 0.0036 - val_MSE: 0.0036 - val_MAE: 0.0551
# Epoch 15/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0024 - MSE: 0.0024 - MAE: 0.0392 - val_loss: 0.0015 - val_MSE: 0.0015 - val_MAE: 0.0329
# Epoch 16/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017 - MSE: 0.0017 - MAE: 0.0325 - val_loss: 8.2617e-04 - val_MSE: 8.2617e-04 - val_MAE: 0.0215
# Epoch 17/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0013 - MSE: 0.0013 - MAE: 0.0274 - val_loss: 5.0021e-04 - val_MSE: 5.0021e-04 - val_MAE: 0.0171
# Epoch 18/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0014 - MSE: 0.0014 - MAE: 0.0269 - val_loss: 7.3495e-04 - val_MSE: 7.3495e-04 - val_MAE: 0.0198
# Epoch 19/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0017 - MSE: 0.0017 - MAE: 0.0295 - val_loss: 5.2038e-04 - val_MSE: 5.2038e-04 - val_MAE: 0.0168
# Epoch 20/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0013 - MSE: 0.0013 - MAE: 0.0256 - val_loss: 6.8622e-04 - val_MSE: 6.8622e-04 - val_MAE: 0.0219
# Epoch 00020: early stopping

# %% [markdown]
# This model is slightly fined tuned to reach the lowest validation loss. In this example, we reach a validation loss of 0.14% with an MSE (Mean Square Error) of **6.4448e-04%** which is relatively good, providing us with a very accurate result.
#
# We can try decreasing the patience of the model to observe how soon the model gets trained.
# Increasing the patience too much might result in ove-training the model.

# %%
plt.plot(history.history['loss'], color = 'red')
plt.plot(history.history['val_loss'], color = 'blue')

# %%
predicted_stateful = regressor.predict(testX)
plt.plot(testY, color = 'red',label = 'Actual Closing Prices')
plt.plot(predicted_stateful.flatten(), color = 'blue', label  = 'Predicted closing Prices')
plt.xlabel('Days')
plt.ylabel('Normalised Prices')
plt.legend(loc='best')
plt.show()

# %%
# Predicting even further in future based on non-current data
predicted_stateful = regressor.predict(validX)
plt.plot(validY, color = 'green',label = 'Actual Closing Prices')
plt.plot(predicted_stateful.flatten(), color = 'cyan', label  = 'Predicted closing Prices')
plt.xlabel('Days')
plt.ylabel('Normalised Prices')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## References/Read More :
# https://www.slideshare.net/LimZhiYuanZane/deep-learning-for-stock-prediction
# https://www.youtube.com/watch?v=Yq-yPc9qVyA
# https://jordicorbilla.github.io/stock-prediction-deep-neural-learning/
# https://www.youtube.com/watch?v=H6du_pfuznE #remove
